# %%
import threading
import time

# %%
counter = 0

def myFun(index):
    global counter
    counter += 1
    print("Counter in thread: {}".format(counter))
   # time.sleep(1)

for i in range(100):
    threading.Thread(target = myFun, args = (i, )).start()
    
print("Counter after thread: {}".format(counter))
# Out:
# Counter in thread: 1Counter in thread: 2
#
# Counter in thread: 3
# Counter in thread: 4Counter in thread: 5
# Counter in thread: 6
#
# Counter in thread: 7
# Counter in thread: 8
# Counter in thread: 9
# Counter in thread: 10
# Counter in thread: 11
# Counter in thread: 12Counter in thread: 13
# Counter in thread: 14
#
# Counter in thread: 15
# Counter in thread: 16Counter in thread: 17
# Counter in thread: 18
#
# Counter in thread: 19Counter in thread: 20
#
# Counter in thread: 21Counter in thread: 22
# Counter in thread: 23Counter in thread: 24
#
#
# Counter in thread: 25Counter in thread: 26
#
# Counter in thread: 27
# Counter in thread: 28Counter in thread: 29
#
# Counter in thread: 30Counter in thread: 31
#
# Counter in thread: 32
# Counter in thread: 33
# Counter in thread: 34
# Counter in thread: 35Counter in thread: 36
#
# Counter in thread: 37
# Counter in thread: 38Counter in thread: 39
#
# Counter in thread: 40
# Counter in thread: 41
# Counter in thread: 42
# ...
