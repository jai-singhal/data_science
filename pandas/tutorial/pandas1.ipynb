# %% [markdown]
# # Chapter 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bikes_df = pd.read_csv("./pandas-cookbook/data/bikes.csv", encoding="utf8")
bikes_df.head(10)
# Out:
#          Date  Berri 1  Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  \
# 0  01/01/2012       35                 0             38             51
# 1  02/01/2012       83                 1             68            153
# 2  03/01/2012      135                 2            104            248
# 3  04/01/2012      144                 1            116            318
# 4  05/01/2012      197                 2            124            330
# 5  06/01/2012      146                 0             98            244
# 6  07/01/2012       98                 2             80            108
# 7  08/01/2012       95                 1             62             98
# 8  09/01/2012      244                 2            165            432
# 9  10/01/2012      397                 3            238            563
#
#    du Parc  Pierre-Dupuy  Rachel1
# 0       26            10       16
# 1       53             6       43
# 2       89             3       58
# 3      111             8       61
# 4       97            13       95
# 5       86             4       75
# 6       53             6       54
# 7       64            11       63
# 8      198            12      173
# 9      275            18      241

# %%
bikes_df[2:5]
# Out:
#          Date  Berri 1  Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  \
# 2  03/01/2012      135                 2            104            248
# 3  04/01/2012      144                 1            116            318
# 4  05/01/2012      197                 2            124            330
#
#    du Parc  Pierre-Dupuy  Rachel1
# 2       89             3       58
# 3      111             8       61
# 4       97            13       95

# %%
bikes_df['Berri 1'].head()
# Out:
# 0     35
# 1     83
# 2    135
# 3    144
# 4    197
# Name: Berri 1, dtype: int64

# %%
#pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
bikes_df['Berri 1'].plot()

# %%
bikes_df.plot()
