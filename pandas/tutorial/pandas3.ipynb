# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
try:
    import seaborn
except ImportError:
    pass

# %%
titanic_data = pd.read_csv("./data/titanic.csv", encoding = "utf8")

titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.sort_values(ascending=True, by = "Fare")
# Out:
#      PassengerId  Survived  Pclass  \
# 271          272         1       3
# 597          598         0       3
# 302          303         0       3
# 633          634         0       1
# 277          278         0       2
# 413          414         0       2
# 674          675         0       2
# 263          264         0       1
# 466          467         0       2
# 732          733         0       2
# 179          180         0       3
# 806          807         0       1
# 481          482         0       2
# 822          823         0       1
# 815          816         0       1
# 378          379         0       3
# 872          873         0       1
# 326          327         0       3
# 843          844         0       3
# 818          819         0       3
# 371          372         0       3
# 202          203         0       3
# 654          655         0       3
# 143          144         0       3
# 411          412         0       3
# ...

# %%
titanic_data['Age'].plot(kind = "hist", figsize = (10, 8))

# %%
# dataframe
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries
# Out:
#      area    capital         country  population
# 0   30510   Brussels         Belgium        11.3
# 1  671308      Paris          France        64.3
# 2  357050     Berlin         Germany        81.3
# 3   41526  Amsterdam     Netherlands        16.9
# 4  244820     London  United Kingdom        64.9

# %%
countries.set_index('country')
# Out:
#                   area    capital  population
# country
# Belgium          30510   Brussels        11.3
# France          671308      Paris        64.3
# Germany         357050     Berlin        81.3
# Netherlands      41526  Amsterdam        16.9
# United Kingdom  244820     London        64.9

# %%
countries.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5c24f21160>,
# ...
#       dtype=object)

# %%
#selecting columns
countries[['capital', 'population']]
# Out:
#      capital  population
# 0   Brussels        11.3
# 1      Paris        64.3
# 2     Berlin        81.3
# 3  Amsterdam        16.9
# 4     London        64.9

# %%
countries.set_index("country")
# Out:
#                   area    capital  population
# country
# Belgium          30510   Brussels        11.3
# France          671308      Paris        64.3
# Germany         357050     Berlin        81.3
# Netherlands      41526  Amsterdam        16.9
# United Kingdom  244820     London        64.9

# %%
# Out:
# RangeIndex(start=0, stop=5, step=1)
