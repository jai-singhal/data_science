# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
try:
    import seaborn
except ModuleNotFoundError:
    pass

# %%
titanic_df = pd.read_csv("./data/titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
print(titanic_df.groupby('Sex')['Survived'].aggregate(lambda x: sum(x)))
titanic_df.groupby('Sex')['Survived'].aggregate(lambda x: sum(x)/len(x)*100).plot(kind = 'bar')
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %% [markdown]
# # New data and basic and info

# %%
data = pd.read_csv("./data/20000101_20161231-NO2.csv", 
                       encoding="utf8", sep = ";",
                       parse_dates=True, skiprows=[0],
                       index_col= 0, na_values = ['n/d'])

data
# Out:
#                      microg/m3  microg/m3.1  microg/m3.2  microg/m3.3
# 2000-01-01 01:00:00      108.0          NaN         65.0         47.0
# 2000-01-01 02:00:00      104.0         60.0         77.0         42.0
# 2000-01-01 03:00:00       97.0         58.0         73.0         34.0
# 2000-01-01 04:00:00       77.0         52.0         57.0         29.0
# 2000-01-01 05:00:00       79.0         52.0         64.0         28.0
# 2000-01-01 06:00:00       67.0         48.0         64.0         37.0
# 2000-01-01 07:00:00       60.0         50.0         58.0         38.0
# 2000-01-01 08:00:00       62.0         43.0         60.0         26.0
# 2000-01-01 09:00:00       66.0         40.0         61.0         35.0
# 2000-01-01 10:00:00       67.0         44.0         56.0         28.0
# 2000-01-01 11:00:00       72.0         51.0         53.0         29.0
# 2000-01-01 12:00:00       82.0         59.0         59.0         29.0
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2000-01-01 01:00:00', '2000-01-01 02:00:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 05:00:00', '2000-01-01 06:00:00',
#                '2000-01-01 07:00:00', '2000-01-01 08:00:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:00:00',
#                ...
#                '2016-12-31 14:00:00', '2016-12-31 15:00:00',
#                '2016-12-31 16:00:00', '2016-12-31 17:00:00',
#                '2016-12-31 18:00:00', '2016-12-31 19:00:00',
#                '2016-12-31 20:00:00', '2016-12-31 21:00:00',
#                '2016-12-31 22:00:00', '2016-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=149039, freq=None)

# %%
data.columns
# Out:
# Index(['microg/m3', 'microg/m3.1', 'microg/m3.2', 'microg/m3.3'], dtype='object')

# %%
data.dtypes
# Out:
# microg/m3      float64
# microg/m3.1    float64
# microg/m3.2    float64
# microg/m3.3    float64
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of                      microg/m3  microg/m3.1  microg/m3.2  microg/m3.3
# 2000-01-01 01:00:00      108.0          NaN         65.0         47.0
# 2000-01-01 02:00:00      104.0         60.0         77.0         42.0
# 2000-01-01 03:00:00       97.0         58.0         73.0         34.0
# 2000-01-01 04:00:00       77.0         52.0         57.0         29.0
# 2000-01-01 05:00:00       79.0         52.0         64.0         28.0
# 2000-01-01 06:00:00       67.0         48.0         64.0         37.0
# 2000-01-01 07:00:00       60.0         50.0         58.0         38.0
# 2000-01-01 08:00:00       62.0         43.0         60.0         26.0
# 2000-01-01 09:00:00       66.0         40.0         61.0         35.0
# 2000-01-01 10:00:00       67.0         44.0         56.0         28.0
# 2000-01-01 11:00:00       72.0         51.0         53.0         29.0
# 2000-01-01 12:00:00       82.0         59.0         59.0         29.0
# ...

# %% [markdown]
# ## Create a Dataframe

# %%
dataframe = {
    "country": ["India", "USA", "China", "Belgium"],
    'population': [11.3, 64.3, 81.3, 16.9],
    'area': [30510, 671308, 357050, 41526],
    'capital': ['Delhi', 'WASHINGTON', 'Berlin', 'Amsterdam']   
}
newpd = pd.DataFrame(dataframe)

# %%
mean_area = newpd['area'].mean()
mean_area
# Out:
# 275098.5

# %%
area = newpd['area']
area[area>mean_area]
# Out:
# 1    671308
# 2    357050
# Name: area, dtype: int64

# %%
newpd.describe()
# Out:
#                 area  population
# count       4.000000    4.000000
# mean   275098.500000   43.450000
# std    304454.519499   34.669247
# min     30510.000000   11.300000
# 25%     38772.000000   15.500000
# 50%    199288.000000   40.600000
# 75%    435614.500000   68.550000
# max    671308.000000   81.300000

# %%
area*100
# Out:
# 0     3051000
# 1    67130800
# 2    35705000
# 3     4152600
# Name: area, dtype: int64

# %%
newpd
# Out:
#      area     capital  country  population
# 0   30510       Delhi    India        11.3
# 1  671308  WASHINGTON      USA        64.3
# 2  357050      Berlin    China        81.3
# 3   41526   Amsterdam  Belgium        16.9

# %%
newpd['area'].median()
# Out:
# 199288.0

# %%
data.plot(kind = "hist", bins = 50)

# %%
data.plot(figsize=(15, 10))

# %%
df = pd.read_csv("./data/titanic.csv")
print("Mean age of male who died in titanic ship: {}".format(df[df['Sex'] == "male"]['Age'].mean()))
df[df['Sex'] == "male"].mean()
# Out:
# Mean age of male who died in titanic ship: 30.72664459161148
# PassengerId    454.147314
# Survived         0.188908
# Pclass           2.389948
# Age             30.726645
# SibSp            0.429809
# Parch            0.235702
# Fare            25.523893
# dtype: float64

# %%
df.loc[df['Sex'] == "female", 'Age'].mean()
# Out:
# 27.915708812260537

# %%
df.loc[df['Sex'] == "female", 'Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 14     14.0
# 15     55.0
# 18     31.0
# 19      NaN
# 22     15.0
# 24      8.0
# 25     38.0
# 28      NaN
# 31      NaN
# 32      NaN
# 38     18.0
# 39     14.0
# 40     40.0
# 41     27.0
# 43      3.0
# 44     19.0
# 47      NaN
# 49     18.0
# 52     49.0
# 53     29.0
# 56     21.0
# 58      5.0
# 61     38.0
#        ...
# 807    18.0
# 809    33.0
# 813     6.0
# 816    23.0
# 820    52.0
# 823    27.0
# 829    62.0
# 830    15.0
# 835    39.0
# 842    30.0
# 849     NaN
# 852     9.0
# 853    16.0
# 854    44.0
# 855    18.0
# 856    45.0
# 858    24.0
# 862    48.0
# 863     NaN
# 865    42.0
# 866    27.0
# 871    47.0
# 874    28.0
# 875    15.0
# 879    56.0
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# 888     NaN
# Name: Age, Length: 314, dtype: float64

# %%
# passengers older than 70

len(df.loc[df['Age'] > 70])
# Out:
# 5

# %%
df = pd.DataFrame({
        "key": ["A", "B", "A", "C", "A", "B", "B", "C"],
        "data": [1, 12, 8, 4, 123, 44, 5 , 9]
    })

# %%
df
# Out:
#   key  value
# 0   A      1
# 1   B     12
# 2   A      8
# 3   C      4
# 4   A    123
# 5   B     44
# 6   B      5
# 7   C      9

# %%
df.groupby("key").sum()
# Out:
#      data
# key
# A     132
# B      61
# C      13

# %%
#or
df.groupby("key").aggregate(np.sum)
# Out:
#      data
# key
# A     132
# B      61
# C      13

# %%
#or
df.groupby("key")['data'].sum()
# Out:
# key
# A    132
# B     61
# C     13
# Name: data, dtype: int64

# %%
df = pd.read_csv("./data/titanic.csv", encoding = "utf8")
df['Survived'].mean()
# Out:
# 0.3838383838383838

# %%
df.groupby('Sex')['Age', 'Fare'].mean()
# Out:
#               Age       Fare
# Sex
# female  27.915709  44.479818
# male    30.726645  25.523893

# %%
#calculate the total ratio for all the passengers yunger than 25
df[df['Age'] <= 25]['Survived'].sum()/sum(df['Survived'])
# Out:
# 0.36257309941520466

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
data = pd.read_csv("./data/20000101_20161231-NO2.csv", 
                       encoding="utf8", sep = ";",
                       parse_dates=True, skiprows=[0],
                       index_col= 0, na_values = ['n/d'])

# %%
data.resample('A')
# Out:
# DatetimeIndexResampler [freq=<YearEnd: month=12>, axis=0, closed=right, label=right, convention=start, base=0]
